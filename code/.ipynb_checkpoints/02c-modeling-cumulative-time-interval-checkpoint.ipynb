# %% [markdown]
# # FOR REFERENCE
# not used in analysis

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from math import radians, cos, sin, asin, sqrt
import datetime as dt

import sklearn.metrics as metrics

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, LabelEncoder
from sklearn.feature_selection import f_classif, SelectKBest
from sklearn.pipeline import Pipeline

import warnings
warnings.filterwarnings('ignore')

pd.set_option("display.max_columns", 60)
pd.set_option("display.max_rows", 500)
# %matplotlib inline
sns.set()

# %% [markdown]
# ## Read Data

# %%
df_twn_hkg_flights = pd.read_csv('../data/filtered_flights_twn_hkg.csv', index_col=0)

# %%
df_twn_hkg_flights.head()
# Out:
#   flight_id  timestamp_utc   latitude   longitude  altitude  heading  speed  \
# 0   c0aabc0     1483194745  25.090073  121.237190       950       46    143
# 1   c0aabc0     1483194754  25.093964  121.242012      1375       48    145
# 2   c0aabc0     1483194770  25.101013  121.251183      2100       50    153
# 3   c0aabc0     1483194776  25.103577  121.254631      2300       50    159
# 4   c0aabc0     1483194782  25.107010  121.259155      2525       50    171
#
#   flight_callsign     aircraft_model aircraft_registration  \
# 0         CAL5821  Boeing 747-409(F)               B-18717
# 1         CAL5821  Boeing 747-409(F)               B-18717
# 2         CAL5821  Boeing 747-409(F)               B-18717
# 3         CAL5821  Boeing 747-409(F)               B-18717
# 4         CAL5821  Boeing 747-409(F)               B-18717
#
#                 airline                                origin  \
# 0  China Airlines Cargo  Taiwan Taoyuan International Airport
# 1  China Airlines Cargo  Taiwan Taoyuan International Airport
# 2  China Airlines Cargo  Taiwan Taoyuan International Airport
# 3  China Airlines Cargo  Taiwan Taoyuan International Airport
# 4  China Airlines Cargo  Taiwan Taoyuan International Airport
#
#                        destination  scheduled_departure_utc  \
# 0  Hong Kong International Airport             1.483193e+09
# 1  Hong Kong International Airport             1.483193e+09
# 2  Hong Kong International Airport             1.483193e+09
# 3  Hong Kong International Airport             1.483193e+09
# 4  Hong Kong International Airport             1.483193e+09
#
#    scheduled_arrival_utc  real_departure_utc  estimated_arrival_utc  \
# 0           1.483198e+09        1.483195e+09                    NaN
# 1           1.483198e+09        1.483195e+09                    NaN
# 2           1.483198e+09        1.483195e+09                    NaN
# 3           1.483198e+09        1.483195e+09                    NaN
# 4           1.483198e+09        1.483195e+09                    NaN
#
#    real_flight_duration scheduled_departure_dt scheduled_arrival_dt  \
# 0                4663.0    2016-12-31 22:00:00  2016-12-31 23:30:00
# 1                4663.0    2016-12-31 22:00:00  2016-12-31 23:30:00
# 2                4663.0    2016-12-31 22:00:00  2016-12-31 23:30:00
# 3                4663.0    2016-12-31 22:00:00  2016-12-31 23:30:00
# 4                4663.0    2016-12-31 22:00:00  2016-12-31 23:30:00
#
#      real_departure_dt estimated_arrival_dt  scheduled_arrival_year  \
# 0  2016-12-31 22:32:05                  NaN                    2016
# 1  2016-12-31 22:32:05                  NaN                    2016
# 2  2016-12-31 22:32:05                  NaN                    2016
# 3  2016-12-31 22:32:05                  NaN                    2016
# 4  2016-12-31 22:32:05                  NaN                    2016
#
#    scheduled_arrival_month  scheduled_arrival_day  scheduled_departure_year  \
# 0                       12                     31                      2016
# 1                       12                     31                      2016
# 2                       12                     31                      2016
# 3                       12                     31                      2016
# 4                       12                     31                      2016
#
#    scheduled_departure_month  scheduled_departure_day  \
# 0                         12                       31
# 1                         12                       31
# 2                         12                       31
# 3                         12                       31
# 4                         12                       31
#
#    scheduled_flight_duration  \
# 0                     5400.0
# 1                     5400.0
# 2                     5400.0
# 3                     5400.0
# 4                     5400.0
#
#                                                route      speed_interval  \
# 0  Taiwan Taoyuan International Airport -> Hong K...  100 <= speed < 200
# 1  Taiwan Taoyuan International Airport -> Hong K...  100 <= speed < 200
# 2  Taiwan Taoyuan International Airport -> Hong K...  100 <= speed < 200
# 3  Taiwan Taoyuan International Airport -> Hong K...  100 <= speed < 200
# 4  Taiwan Taoyuan International Airport -> Hong K...  100 <= speed < 200
#
#    time_since_real_departure  prev_latitude  prev_longitude  \
# 0                       20.0      25.072781      121.218529
# 1                       29.0      25.090073      121.237190
# 2                       45.0      25.093964      121.242012
# 3                       51.0      25.101013      121.251183
# 4                       57.0      25.103577      121.254631
#
#    calculated_flight_duration  calculated_time_before_arrival  \
# 0                      5115.0                          5095.0
# 1                      5115.0                          5086.0
# 2                      5115.0                          5070.0
# 3                      5115.0                          5064.0
# 4                      5115.0                          5058.0
#
#    displacement_to_hkg  displacement_fr_twn  \
# 0           806.651564             2.544945
# 1           807.260143             3.189686
# 2           808.403669             4.392177
# 3           808.830179             4.838551
# 4           809.392567             5.430343
#
#   minutes_since_real_departure_interval
# 0                         0 <= min < 10
# 1                         0 <= min < 10
# 2                         0 <= min < 10
# 3                         0 <= min < 10
# 4                         0 <= min < 10

# %%
df_twn_hkg_flights['scheduled_departure_dt'] = pd.to_datetime(df_twn_hkg_flights['scheduled_departure_dt'])
df_twn_hkg_flights['scheduled_arrival_dt'] = pd.to_datetime(df_twn_hkg_flights['scheduled_arrival_dt'])
df_twn_hkg_flights['real_departure_dt'] = pd.to_datetime(df_twn_hkg_flights['real_departure_dt'])
df_twn_hkg_flights['estimated_arrival_dt'] = pd.to_datetime(df_twn_hkg_flights['estimated_arrival_dt'])

# %%
df_twn_hkg_flights.dtypes
# Out:
# flight_id                                        object
# timestamp_utc                                     int64
# latitude                                        float64
# longitude                                       float64
# altitude                                          int64
# heading                                           int64
# speed                                             int64
# flight_callsign                                  object
# aircraft_model                                   object
# aircraft_registration                            object
# airline                                          object
# origin                                           object
# destination                                      object
# scheduled_departure_utc                         float64
# scheduled_arrival_utc                           float64
# real_departure_utc                              float64
# estimated_arrival_utc                           float64
# real_flight_duration                            float64
# scheduled_departure_dt                   datetime64[ns]
# scheduled_arrival_dt                     datetime64[ns]
# real_departure_dt                        datetime64[ns]
# estimated_arrival_dt                     datetime64[ns]
# scheduled_arrival_year                            int64
# scheduled_arrival_month                           int64
# scheduled_arrival_day                             int64
# scheduled_departure_year                          int64
# scheduled_departure_month                         int64
# scheduled_departure_day                           int64
# scheduled_flight_duration                       float64
# route                                            object
# speed_interval                                   object
# time_since_real_departure                       float64
# prev_latitude                                   float64
# prev_longitude                                  float64
# calculated_flight_duration                      float64
# calculated_time_before_arrival                  float64
# displacement_to_hkg                             float64
# displacement_fr_twn                             float64
# minutes_since_real_departure_interval            object
# dtype: object

# %% [markdown]
# **Correlation of numerical variables**

# %%
# # Set the default matplotlib figure size to 7x7:
# fix, ax = plt.subplots(figsize=(7,7))

# # Generate a mask for the upper triangle (taken from seaborn example gallery)
# mask = np.zeros_like(wine_corr, dtype=np.bool)
# mask[np.triu_indices_from(mask)] = True

# # Plot the heatmap with seaborn.
# # Assign the matplotlib axis the function returns. This will let us resize the labels.
# ax = sns.heatmap(wine_corr, mask=mask, ax=ax)

# # Resize the labels.
# ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14)
# ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14)

# # If you put plt.show() at the bottom, it prevents those useless printouts from matplotlib.
# plt.show()

# %% [markdown]
# **ANOVA of categorical (nominal) variables**

# %% [markdown]
# ## Modeling

# %%
df_twn_hkg_flights.columns
# Out:
# Index(['flight_id', 'timestamp_utc', 'latitude', 'longitude', 'altitude',
#        'heading', 'speed', 'flight_callsign', 'aircraft_model',
#        'aircraft_registration', 'airline', 'origin', 'destination',
#        'scheduled_departure_utc', 'scheduled_arrival_utc',
#        'real_departure_utc', 'estimated_arrival_utc', 'real_flight_duration',
#        'scheduled_departure_dt', 'scheduled_arrival_dt', 'real_departure_dt',
#        'estimated_arrival_dt', 'scheduled_arrival_year',
#        'scheduled_arrival_month', 'scheduled_arrival_day',
#        'scheduled_departure_year', 'scheduled_departure_month',
#        'scheduled_departure_day', 'scheduled_flight_duration', 'route',
#        'speed_interval', 'time_since_real_departure', 'prev_latitude',
#        'prev_longitude', 'calculated_flight_duration',
#        'calculated_time_before_arrival', 'displacement_to_hkg',
#        'displacement_fr_twn', 'minutes_since_real_departure_interval'],
#       dtype='object')

# %%
df_twn_hkg_flights['minutes_since_real_departure_interval'].value_counts().sort_index()
# Out:
# 0 <= min < 10       28142
# 10 <= min < 20       8345
# 100 <= min < 110     4672
# 110 <= min < 120      508
# 20 <= min < 30       8911
# 30 <= min < 40       7510
# 40 <= min < 50       8422
# 50 <= min < 60       8396
# 60 <= min < 70      13213
# 70 <= min < 80      33006
# 80 <= min < 90      33812
# 90 <= min < 100     16829
# Name: minutes_since_real_departure_interval, dtype: int64

# %%
# Select 0 <= min 40
mask = df_twn_hkg_flights['minutes_since_real_departure_interval'].isin(['0 <= min < 10',
                                                                         '10 <= min < 20',
                                                                         '20 <= min < 30',
                                                                         '30 <= min < 40'])

df_for_modeling = df_twn_hkg_flights[mask].groupby(['flight_id'])\
                  ['time_since_real_departure'].max().reset_index()

df_for_modeling
# Out:
#     flight_id  time_since_real_departure
# 0     c0aabc0                     2294.0
# 1     c0ab750                     2316.0
# 2     c0ac71c                     2311.0
# 3     c0b5e1f                     2291.0
# 4     c0b6e4a                     2284.0
# ..        ...                        ...
# 782   c524f43                     2292.0
# 783   c5285c7                     2293.0
# 784   c528666                     2317.0
# 785   c528860                     2304.0
# 786   c52959e                     2339.0
#
# [787 rows x 2 columns]

# %%
df_combined = pd.merge(df_for_modeling,
                      df_twn_hkg_flights,
                      on=['flight_id', 
                          'time_since_real_departure'])

df_combined
# Out:
#     flight_id  time_since_real_departure  timestamp_utc   latitude  \
# 0     c0aabc0                     2294.0     1483197019  22.611099
# 1     c0ab750                     2316.0     1483198807  22.549160
# 2     c0ac71c                     2311.0     1483201388  22.440554
# 3     c0b5e1f                     2291.0     1483225164  22.536163
# 4     c0b6e4a                     2284.0     1483228124  22.748795
# ..        ...                        ...            ...        ...
# 782   c524f43                     2292.0     1485854698  22.681919
# 783   c5285c7                     2293.0     1485864396  22.750311
# 784   c528666                     2317.0     1485866298  22.703842
# 785   c528860                     2304.0     1485865050  22.644218
# 786   c52959e                     2339.0     1485866989  22.609072
#
#       longitude  altitude  heading  speed flight_callsign     aircraft_model  \
# 0    117.966003     38000      237    430         CAL5821  Boeing 747-409(F)
# 1    117.861740     32000      237    447          CAL921    Airbus A330-302
# 2    117.679237     31975      237    445          PAC215  Boeing 747-46N(F)
# 3    117.840355     40000      237    441          CPA463    Airbus A350-941
# 4    118.194916     38000      237    424          CPA465    Airbus A340-313
# ..          ...       ...      ...    ...             ...                ...
# 782  118.084152     35975      237    406          EVA871    Airbus A330-203
# 783  118.198242     32000      237    403          CAL927     Boeing 737-809
# 784  118.120552     36000      237    422          CPA451     Boeing 777-367
# 785  118.021034     43000      237    415          CPA401    Airbus A350-941
# 786  117.962952     40000      237    402          CRK283    Airbus A330-223
#
#     aircraft_registration               airline  \
# 0                 B-18717  China Airlines Cargo
# 1                 B-18309        China Airlines
# 2                  N450PA       Polar Air Cargo
# 3                   B-LRG        Cathay Pacific
# 4                   B-HXH        Cathay Pacific
# ..                    ...                   ...
# 782               B-16312               EVA Air
# 783               B-18610        China Airlines
# 784                 B-HNF        Cathay Pacific
# 785                 B-LRA        Cathay Pacific
# 786                 B-LNC    Hong Kong Airlines
#
#                                    origin                      destination  \
# 0    Taiwan Taoyuan International Airport  Hong Kong International Airport
# 1    Taiwan Taoyuan International Airport  Hong Kong International Airport
# 2    Taiwan Taoyuan International Airport  Hong Kong International Airport
# 3    Taiwan Taoyuan International Airport  Hong Kong International Airport
# 4    Taiwan Taoyuan International Airport  Hong Kong International Airport
# ..                                    ...                              ...
# 782  Taiwan Taoyuan International Airport  Hong Kong International Airport
# 783  Taiwan Taoyuan International Airport  Hong Kong International Airport
# 784  Taiwan Taoyuan International Airport  Hong Kong International Airport
# 785  Taiwan Taoyuan International Airport  Hong Kong International Airport
# 786  Taiwan Taoyuan International Airport  Hong Kong International Airport
#
#      scheduled_departure_utc  scheduled_arrival_utc  real_departure_utc  \
# 0               1.483193e+09           1.483198e+09        1.483195e+09
# 1               1.483194e+09           1.483200e+09        1.483196e+09
# 2               1.483198e+09           1.483204e+09        1.483199e+09
# 3               1.483222e+09           1.483228e+09        1.483223e+09
# 4               1.483226e+09           1.483232e+09        1.483226e+09
# ..                       ...                    ...                 ...
# 782             1.485852e+09           1.485858e+09        1.485852e+09
# 783             1.485861e+09           1.485868e+09        1.485862e+09
# 784             1.485863e+09           1.485870e+09        1.485864e+09
# 785             1.485862e+09           1.485869e+09        1.485863e+09
# 786             1.485864e+09           1.485872e+09        1.485865e+09
#
#      estimated_arrival_utc  real_flight_duration scheduled_departure_dt  \
# 0                      NaN                4663.0    2016-12-31 22:00:00
# 1                      NaN                5125.0    2016-12-31 22:15:00
# 2                      NaN                5155.0    2016-12-31 23:20:00
# 3                      NaN                5103.0    2017-01-01 06:00:00
# 4                      NaN                4992.0    2017-01-01 07:05:00
# ..                     ...                   ...                    ...
# 782                    NaN                5452.0    2017-01-31 16:35:00
# 783                    NaN                5785.0    2017-01-31 19:10:00
# 784                    NaN                5776.0    2017-01-31 19:40:00
# 785                    NaN                5836.0    2017-01-31 19:30:00
# 786                    NaN                5902.0    2017-01-31 20:00:00
#
#     scheduled_arrival_dt   real_departure_dt estimated_arrival_dt  \
# 0    2016-12-31 23:30:00 2016-12-31 22:32:05                  NaT
# 1    2017-01-01 00:05:00 2016-12-31 23:01:31                  NaT
# 2    2017-01-01 01:10:00 2016-12-31 23:44:37                  NaT
# 3    2017-01-01 07:50:00 2017-01-01 06:21:13                  NaT
# 4    2017-01-01 08:55:00 2017-01-01 07:10:40                  NaT
# ..                   ...                 ...                  ...
# 782  2017-01-31 18:25:00 2017-01-31 16:46:46                  NaT
# 783  2017-01-31 21:15:00 2017-01-31 19:28:23                  NaT
# 784  2017-01-31 21:40:00 2017-01-31 19:59:41                  NaT
# 785  2017-01-31 21:30:00 2017-01-31 19:39:06                  NaT
# 786  2017-01-31 22:10:00 2017-01-31 20:10:50                  NaT
#
#      scheduled_arrival_year  scheduled_arrival_month  scheduled_arrival_day  \
# 0                      2016                       12                     31
# 1                      2017                        1                      1
# 2                      2017                        1                      1
# 3                      2017                        1                      1
# 4                      2017                        1                      1
# ..                      ...                      ...                    ...
# 782                    2017                        1                     31
# 783                    2017                        1                     31
# 784                    2017                        1                     31
# 785                    2017                        1                     31
# 786                    2017                        1                     31
#
#      scheduled_departure_year  scheduled_departure_month  \
# 0                        2016                         12
# 1                        2016                         12
# 2                        2016                         12
# 3                        2017                          1
# 4                        2017                          1
# ..                        ...                        ...
# 782                      2017                          1
# 783                      2017                          1
# 784                      2017                          1
# 785                      2017                          1
# 786                      2017                          1
#
#      scheduled_departure_day  scheduled_flight_duration  \
# 0                         31                     5400.0
# 1                         31                     6600.0
# 2                         31                     6600.0
# 3                          1                     6600.0
# 4                          1                     6600.0
# ..                       ...                        ...
# 782                       31                     6600.0
# 783                       31                     7500.0
# 784                       31                     7200.0
# 785                       31                     7200.0
# 786                       31                     7800.0
#
#                                                  route      speed_interval  \
# 0    Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
# 1    Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
# 2    Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
# 3    Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
# 4    Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
# ..                                                 ...                 ...
# 782  Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
# 783  Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
# 784  Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
# 785  Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
# 786  Taiwan Taoyuan International Airport -> Hong K...  400 <= speed < 500
#
#      prev_latitude  prev_longitude  calculated_flight_duration  \
# 0        22.673492      118.069817                      5115.0
# 1        22.653669      118.036751                      4906.0
# 2        22.509064      117.794312                      4896.0
# 3        22.605581      117.957054                      4896.0
# 4        22.842625      118.352051                      4946.0
# ..             ...             ...                         ...
# 782      22.749290      118.196671                      5068.0
# 783      22.812784      118.302765                      5072.0
# 784      22.770609      118.232216                      5471.0
# 785      22.709518      118.129997                      5317.0
# 786      22.702410      118.118591                      5365.0
#
#      calculated_time_before_arrival  displacement_to_hkg  displacement_fr_twn  \
# 0                            2821.0           417.275899           429.504030
# 1                            2590.0           406.176420           442.127430
# 2                            2585.0           386.965839           464.257046
# 3                            2605.0           403.908949           444.738575
# 4                            2662.0           441.940243           401.697130
# ..                              ...                  ...                  ...
# 782                          2776.0           429.957602           415.164611
# 783                          2779.0           442.296015           401.328536
# 784                          3154.0           433.885674           410.741626
# 785                          3013.0           423.171151           422.814108
# 786                          3026.0           416.948315           429.888702
#
#     minutes_since_real_departure_interval
# 0                          30 <= min < 40
# 1                          30 <= min < 40
# 2                          30 <= min < 40
# 3                          30 <= min < 40
# 4                          30 <= min < 40
# ..                                    ...
# 782                        30 <= min < 40
# 783                        30 <= min < 40
# 784                        30 <= min < 40
# 785                        30 <= min < 40
# 786                        30 <= min < 40
#
# [787 rows x 39 columns]

# %%
df_combined['time_since_real_departure'].max()
# Out:
# 2340.0

# %%
2340/60
# Out:
# 39.0

# %%
df_combined['average_velocity'] = df_combined['displacement_fr_twn'] / df_combined['time_since_real_departure']

# %%
selected_features = ['latitude', 'longitude', 
                     'altitude', 'heading', 'speed',
                     'flight_callsign', 'aircraft_registration', 
                     'aircraft_model', 'airline', 
                     'displacement_to_hkg', 'average_velocity']

nominal_features = [
                    'flight_callsign', 'aircraft_registration',
                    'aircraft_model', 'airline']

df_combined[selected_features].head()
# Out:
#     latitude   longitude  altitude  heading  speed flight_callsign  \
# 0  22.611099  117.966003     38000      237    430         CAL5821
# 1  22.549160  117.861740     32000      237    447          CAL921
# 2  22.440554  117.679237     31975      237    445          PAC215
# 3  22.536163  117.840355     40000      237    441          CPA463
# 4  22.748795  118.194916     38000      237    424          CPA465
#
#   aircraft_registration     aircraft_model               airline  \
# 0               B-18717  Boeing 747-409(F)  China Airlines Cargo
# 1               B-18309    Airbus A330-302        China Airlines
# 2                N450PA  Boeing 747-46N(F)       Polar Air Cargo
# 3                 B-LRG    Airbus A350-941        Cathay Pacific
# 4                 B-HXH    Airbus A340-313        Cathay Pacific
#
#    displacement_to_hkg  average_velocity
# 0           417.275899          0.187229
# 1           406.176420          0.190901
# 2           386.965839          0.200890
# 3           403.908949          0.194124
# 4           441.940243          0.175874

# %%
len(df_combined['flight_callsign'].unique())
# Out:
# 78

# %%
len(df_combined['flight_id'].unique())
# Out:
# 787

# %%
def r2_adj(y_true, y_preds, p):
    n = len(y_true)
    y_mean = np.mean(y_true)
    numerator = np.sum(np.square(y_true - y_preds)) / (n - p - 1)
    denominator = np.sum(np.square(y_true - y_mean)) / (n - 1)
    return (1 - (numerator / denominator))

def get_regression_metrics(y_true, y_pred, p):
    mse = metrics.mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
#     msle = metrics.mean_squared_log_error(y_true, y_pred)
    mae = metrics.median_absolute_error(y_true, y_pred)
    r2 = metrics.r2_score(y_true, y_pred)
    r2a = r2_adj(y_true, y_pred, p)
    
    print('Mean squared error      = ', mse)
    print('Root mean squared error = ', rmse)
#     print('Mean squared log error  = ', msle)
    print('Median absolute error   = ', mae)
    print('R^2                     = ', r2)
    print('Adjusted R^2            = ', r2a)
    
    return {
        'mse': mse,
        'rmse': rmse,
#         'msle': msle,
        'mae': mae,
        'r2': r2,
        'r2_adjusted': r2a
    }

# %%
# Train data

# mask = df_twn_hkg_flights['time_since_real_departure'] <= (40*60)
# df_for_modeling = df_twn_hkg_flights[mask].copy()
X = df_combined[selected_features].copy()
y = df_combined['calculated_time_before_arrival'].copy()

# %%
X = pd.get_dummies(X, columns=nominal_features, drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, shuffle=True)

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# X_train.columns

# %%
# plt.figure(figsize=(12,10))
# plt.barh(X_train.columns, linreg.coef_)

# %%
y_train_pred = linreg.predict(X_train)

train_regression_metrics = get_regression_metrics(y_train, y_train_pred, X_train.shape[1])
# Out:
# Mean squared error      =  63021.44327606519
# Root mean squared error =  251.04072035441817
# Median absolute error   =  132.56728936356376
# R^2                     =  0.7427760119467701
# Adjusted R^2            =  0.32411437448774727

# %%
y_test_pred = linreg.predict(X_test)

test_regression_metrics = get_regression_metrics(y_test, y_test_pred, X_test.shape[1])

df_test_true_pred = pd.DataFrame(columns=['true', 'pred'])
df_test_true_pred = df_test_true_pred.assign(true=y_test)
df_test_true_pred = df_test_true_pred.assign(pred=y_test_pred)
df_test_true_pred['diff'] = df_test_true_pred['true'] - df_test_true_pred['pred']
# Out:
# Mean squared error      =  173419.94573438904
# Root mean squared error =  416.4372050314297
# Median absolute error   =  258.77693718470255
# R^2                     =  0.32211630315491446
# Adjusted R^2            =  1.4587402603649933

# %%
sorted(list(zip(X_test.columns, abs(linreg.coef_))), 
    key=lambda item:item[1],
      reverse=True)
# Out:
# [('average_velocity', 3911.157233107849),
#  ('latitude', 1946.4007222513112),
#  ('longitude', 1315.219088280761),
#  ('aircraft_registration_B-LDA', 1033.8140468825202),
#  ('aircraft_model_Airbus A300F4-605R', 951.5744685667033),
#  ('aircraft_registration_B-16212', 924.1950304309453),
#  ('flight_callsign_CPA511', 870.0846486094315),
#  ('flight_callsign_CAL2641', 866.2812355454363),
#  ('flight_callsign_CPA421', 825.4197890940893),
#  ('flight_callsign_CPA451', 802.8529815328213),
#  ('flight_callsign_CPA401', 761.8872640672088),
#  ('aircraft_model_Airbus A300B4-622R(F)', 753.7672170350147),
#  ('flight_callsign_CPA531', 715.2414060880967),
#  ('flight_callsign_CAL921', 676.7390965573385),
#  ('aircraft_registration_B-16208', 666.1078266381517),
#  ('airline_Cathay Pacific', 647.0653125159408),
#  ('aircraft_registration_B-16335', 633.9852740401413),
#  ('flight_callsign_CPA471', 606.5881168154174),
#  ('flight_callsign_CPA403', 597.8825777037534),
#  ('aircraft_registration_B-LBC', 580.0492097860431),
#  ('flight_callsign_CPA473', 575.044064952906),
#  ('aircraft_registration_B-LAZ', 570.0153711408728),
#  ('flight_callsign_CPA475', 566.3929356552893),
#  ('flight_callsign_CAL677', 555.7969660588011),
#  ('aircraft_registration_B-18721', 551.0998314682087),
#  ('aircraft_registration_B-16336', 548.9821311878759),
#  ('airline_Cathay Pacific (Oneworld livery)', 535.5232055879721),
#  ('aircraft_registration_B-LNK', 527.4205785868411),
#  ('aircraft_registration_B-18663', 523.0775139874941),
#  ('aircraft_registration_B-HXJ', 517.4074564381137),
#  ('flight_callsign_CPA495', 517.3194458965727),
#  ('flight_callsign_CAL3921', 514.2868732342727),
#  ('aircraft_registration_B-18723', 505.0598886263781),
#  ('flight_callsign_CRK285', 504.4492096747466),
#  ('flight_callsign_CAL601', 500.7870373653095),
#  ('flight_callsign_CPA25', 500.7438244020598),
#  ('aircraft_registration_B-18610', 500.34576639098015),
#  ('flight_callsign_EVA871', 496.5857779843747),
#  ('aircraft_registration_B-16222', 490.68833500415064),
#  ('aircraft_registration_B-18710', 486.0179359642039),
#  ('flight_callsign_CPA405', 460.7323967475785),
#  ('aircraft_model_Boeing 737-8AL', 460.38092684569835),
#  ('aircraft_registration_B-18722', 459.8599092637554),
#  ('flight_callsign_CPA469', 453.1232602898539),
#  ('flight_callsign_EVA891', 451.60387800692405),
#  ('flight_callsign_BR827', 451.05392503582806),
#  ('flight_callsign_HDA483', 445.4021863904978),
#  ('aircraft_model_Boeing 747-867(F)', 444.87324035297877),
#  ('aircraft_registration_B-LJJ', 444.87324035297166),
#  ('aircraft_registration_B-LIE', 440.91738637556904),
#  ('aircraft_registration_B-16410', 440.1216472763471),
#  ('aircraft_model_Boeing 747-45E', 440.1216472761621),
#  ('aircraft_registration_B-LRE', 439.5592359422601),
#  ('aircraft_registration_N855FD', 436.0902417602539),
#  ('aircraft_registration_B-KPD', 413.1717966076385),
#  ('flight_callsign_EVA809', 411.7106372370904),
#  ('aircraft_model_Airbus A330-203', 409.50233088713844),
#  ('flight_callsign_CAL5823', 408.20851596525773),
#  ('aircraft_registration_B-16708', 406.1255980420407),
#  ('aircraft_registration_B-16717', 405.0577597721613),
#  ('flight_callsign_EVA851', 402.7330101651661),
#  ('aircraft_registration_B-LDN', 399.41424033936084),
#  ('aircraft_registration_B-16215', 398.119678192981),
#  ('aircraft_registration_B-16225', 391.6087890643373),
#  ('flight_callsign_EVA827', 385.59181318215417),
#  ('aircraft_registration_B-LBJ', 381.48014824621976),
#  ('aircraft_registration_B-16226', 369.180125213229),
#  ('aircraft_registration_B-HLW', 361.353660067845),
#  ('aircraft_registration_B-18308', 359.69725037628206),
#  ('aircraft_registration_B-HLI', 356.4897108016757),
#  ('flight_callsign_CAL923', 356.3285729493537),
#  ('aircraft_registration_B-LDM', 354.35297669530837),
#  ('aircraft_registration_B-HLP', 352.9138480769375),
#  ('aircraft_registration_B-LDG', 349.596932557793),
#  ('flight_callsign_EVA855', 348.45989470940856),
#  ('aircraft_registration_B-16216', 348.19035247101965),
#  ('flight_callsign_CPA5', 347.7703607195264),
#  ('aircraft_registration_B-KQC', 347.6162345329492),
#  ('aircraft_registration_B-18720', 346.31142463482337),
#  ('aircraft_registration_B-LBF', 341.82209815514807),
#  ('aircraft_registration_B-KPO', 340.91230535047106),
#  ('aircraft_model_Boeing 737-809', 333.85129198495224),
#  ('flight_callsign_CAL679', 333.45071657855794),
#  ('aircraft_registration_B-HNI', 329.77877789094083),
#  ('aircraft_registration_B-18806', 328.6049967634126),
#  ('flight_callsign_CAL6843', 327.8510498609043),
#  ('aircraft_registration_B-LAM', 322.5543326950627),
#  ('aircraft_registration_B-16206', 320.13057303452496),
#  ('aircraft_registration_B-LNJ', 315.57131643929347),
#  ('aircraft_registration_B-LNC', 312.18426817207194),
#  ('flight_callsign_CAL903', 311.7489466977381),
#  ('flight_callsign_CPA407', 310.9384247044952),
#  ('aircraft_registration_B-16203', 307.2086482763565),
#  ('aircraft_registration_B-LAL', 306.2626059727406),
#  ('aircraft_registration_B-18725', 304.18003629465267),
#  ('aircraft_model_Boeing 737-8MA', 302.9819801108895),
#  ('aircraft_registration_B-18655', 302.98198011066006),
#  ('aircraft_registration_B-HTE', 301.5742166831731),
#  ('flight_callsign_AHK681', 301.34825163580183),
#  ('flight_callsign_CAL927', 296.3164569627903),
#  ('aircraft_registration_B-LDF', 295.11053969344215),
#  ('airline_EVA Air (Hello Kitty-Happy Music Time Livery)', 294.0116523567191),
#  ('aircraft_registration_B-16311', 294.011652356521),
#  ('aircraft_registration_B-LRJ', 291.2273063204614),
#  ('aircraft_registration_B-16223', 289.4976181490057),
#  ('aircraft_registration_B-HNK', 287.97908005639437),
#  ('aircraft_registration_N573FE', 286.6571207506581),
#  ('aircraft_registration_B-HLL', 285.311457839173),
#  ('airline_Cathay Dragon', 283.48961975787574),
#  ('aircraft_registration_B-16227', 282.4787089120235),
#  ('aircraft_registration_B-18653', 280.85448825420286),
#  ('aircraft_model_Boeing 737-8Q8', 280.8544882541843),
#  ('flight_callsign_CAL3641', 280.8544882533411),
#  ('flight_callsign_CAL909', 277.05828029466613),
#  ('flight_callsign_EVA6529', 277.00465757918386),
#  ('aircraft_registration_B-HSU', 275.44983732487674),
#  ('airline_Cathay Pacific Cargo', 275.2854578480281),
#  ('aircraft_registration_B-LAA', 272.6397226164351),
#  ('flight_callsign_HDA867', 272.6397226162651),
#  ('aircraft_registration_B-KQW', 270.7892867432044),
#  ('flight_callsign_EVA6535', 257.0384521822185),
#  ('aircraft_registration_B-18317', 256.52057468308),
#  ('flight_callsign_CAL5833', 255.5900713173794),
#  ('aircraft_registration_B-18718', 253.74671637014632),
#  ('aircraft_registration_B-16482', 253.54723796749326),
#  ('aircraft_registration_B-LAE', 253.4891902494358),
#  ('flight_callsign_CPA565', 251.24445316562287),
#  ('flight_callsign_CPA2025', 249.28411276270697),
#  ('aircraft_registration_B-HLF', 248.25909254459538),
#  ('aircraft_registration_B-HNN', 247.40365909756997),
#  ('aircraft_registration_B-18302', 247.0946782119865),
#  ('aircraft_registration_B-16219', 244.32260157822193),
#  ('airline_EVA Air', 242.9471419254823),
#  ('aircraft_registration_B-18902', 242.54348096567162),
#  ('aircraft_model_Airbus A330-243F', 242.3709787425355),
#  ('flight_callsign_CRK9269', 242.37097874222997),
#  ('aircraft_registration_B-LDB', 242.12034801062606),
#  ('flight_callsign_CAL641', 238.17444515841586),
#  ('aircraft_registration_B-16312', 234.08769090915274),
#  ('airline_FedEx', 228.83216743687484),
#  ('airline_EVA Air (Star Alliance Livery)', 228.0970560614959),
#  ('aircraft_registration_B-LAJ', 227.90248184065044),
#  ('aircraft_model_Airbus A321-231', 227.01385608051385),
#  ('aircraft_registration_B-LRF', 221.49292201395482),
#  ('aircraft_registration_B-LAX', 221.16899275853996),
#  ('airline_Polar Air Cargo', 220.65988405755903),
#  ('flight_callsign_PAC215', 220.65988405741862),
#  ('aircraft_registration_B-16702', 220.43186243201254),
#  ('flight_callsign_CAL919', 220.28495534101634),
#  ('aircraft_registration_B-18606', 219.27309512914107),
#  ('aircraft_registration_B-LAC', 216.60960312455722),
#  ('aircraft_registration_B-HLT', 216.2307357604668),
#  ('aircraft_registration_B-HLU', 215.77907282504225),
#  ('aircraft_registration_B-HLA', 215.5379871058999),
#  ('aircraft_registration_B-HSO', 215.10573615297295),
#  ('aircraft_registration_B-KPH', 213.33363509370642),
#  ('flight_callsign_CAL5837', 212.75370437766324),
#  ('flight_callsign_CAL5835', 211.62991349465204),
#  ('aircraft_registration_B-KPR', 210.81432936267407),
#  ('airline_Hong Kong Airlines', 205.86125509882783),
#  ('aircraft_model_Boeing 777-367(ER)', 205.3015013561767),
#  ('aircraft_registration_B-LBI', 204.62063200000892),
#  ('aircraft_registration_B-18303', 204.02088579190504),
#  ('airline_China Airlines', 201.3177868274331),
#  ('flight_callsign_CRK255', 199.99345615103576),
#  ('aircraft_registration_B-18306', 199.90673922021944),
#  ('aircraft_registration_B-LRM', 199.88275064700213),
#  ('aircraft_registration_N885FD', 199.32621392390539),
#  ('aircraft_registration_B-HNM', 197.18814677334518),
#  ('aircraft_registration_N498MC', 197.09053821911894),
#  ('aircraft_model_Boeing 747-47U(F)', 197.09053821911215),
#  ('aircraft_registration_B-18051', 195.81603327647372),
#  ('aircraft_registration_B-18612', 194.2790712684045),
#  ('flight_callsign_CAL5825', 193.9872347070227),
#  ('aircraft_registration_B-18709', 193.98723470624407),
#  ('aircraft_registration_B-LAO', 193.5757349053222),
#  ('flight_callsign_EVA869', 192.04848064159455),
#  ('flight_callsign_CRK283', 190.43791136882473),
#  ('airline_EVA Air Cargo', 189.69521611753976),
#  ('aircraft_registration_B-LRI', 189.659792181074),
#  ('aircraft_registration_B-18007', 187.99389623455704),
#  ('airline_China Airlines (Boeing Livery)', 187.99389623453172),
#  ('aircraft_registration_B-KPP', 187.5161234466589),
#  ('aircraft_registration_B-HNJ', 187.42242487387782),
#  ('aircraft_registration_B-LRB', 186.96862599455923),
#  ('aircraft_registration_N623FE', 186.18704064656126),
#  ('aircraft_registration_N583UP', 183.9794560434142),
#  ('flight_callsign_CPA467', 183.3217204253895),
#  ('aircraft_registration_B-KPL', 179.68643474201994),
#  ('aircraft_registration_B-LIC', 178.18257821408852),
#  ('flight_callsign_CPA3273', 178.1825782138949),
#  ('aircraft_model_Boeing 777-36N(ER)', 175.89235732971696),
#  ('aircraft_registration_B-KPN', 175.49705045919794),
#  ('aircraft_registration_B-18605', 174.96756095062202),
#  ('aircraft_registration_B-HNL', 171.51300813311758),
#  ('aircraft_registration_B-LAK', 170.23610451548652),
#  ('aircraft_model_Boeing 747-467F(ER)', 169.58778250495195),
#  ('aircraft_model_Boeing 777-309(ER)', 169.48904052543818),
#  ('aircraft_registration_B-LNG', 167.81164094150944),
#  ('aircraft_registration_B-HNG', 165.60945796005325),
#  ('aircraft_registration_B-HTG', 164.6585600322337),
#  ('aircraft_registration_B-LNQ', 163.53847684166993),
#  ('aircraft_registration_B-18310', 160.122633373344),
#  ('aircraft_registration_B-LBH', 158.3080874117062),
#  ('aircraft_registration_B-LNS', 157.96598786834576),
#  ('aircraft_registration_B-16217', 156.28695724664553),
#  ('aircraft_model_Boeing 747-409(F)', 155.61625983057957),
#  ('airline_China Airlines Cargo', 155.61625983049544),
#  ('aircraft_registration_B-LAD', 155.54285369161772),
#  ('aircraft_registration_B-LAR', 155.3624217346509),
#  ('flight_callsign_CRK253', 150.52756579887202),
#  ('aircraft_registration_B-16218', 147.94128373847235),
#  ('airline_Eva Air', 147.94128373814922),
#  ('aircraft_registration_B-18307', 146.68522048021717),
#  ('aircraft_registration_B-18309', 146.08710533199996),
#  ('aircraft_registration_B-18717', 144.9108708857355),
#  ('aircraft_registration_B-HLO', 144.41717637174867),
#  ('aircraft_registration_B-16716', 143.09312810387803),
#  ('aircraft_registration_B-18312', 143.06062836282098),
#  ('aircraft_registration_B-18701', 142.3626247724423),
#  ('aircraft_registration_N861FD', 142.07292300885962),
#  ('aircraft_model_Boeing 747-45EF(SCD)', 141.7367270995329),
#  ('aircraft_registration_B-HXG', 140.0576980218476),
#  ('aircraft_registration_B-LDE', 138.1639036590347),
#  ('flight_callsign_CAL5821', 137.98542122503338),
#  ('aircraft_registration_B-LNP', 136.94246458615436),
#  ('aircraft_model_Airbus A320-232', 136.31631257027323),
#  ('flight_callsign_FDX9171', 134.1410626088123),
#  ('aircraft_model_McDonnell Douglas MD-11F', 134.14106260864892),
#  ('flight_callsign_EVA6521', 133.49584770960337),
#  ('aircraft_registration_B-HLH', 131.57136455614477),
#  ('aircraft_registration_N582UP', 130.96667295469342),
#  ('aircraft_registration_B-18716', 129.26072162338656),
#  ('aircraft_registration_B-HLK', 128.9158994797931),
#  ('aircraft_registration_B-HSK', 128.78916909384313),
#  ('aircraft_model_Airbus A330-342', 128.34784158162165),
#  ('aircraft_registration_B-LRG', 127.351241947532),
#  ('aircraft_registration_B-LBK', 127.2315409110188),
#  ('aircraft_model_Airbus A321-211', 126.66470804936955),
#  ('aircraft_registration_B-HNC', 121.06731843107644),
#  ('aircraft_registration_B-LNL', 120.89654078644531),
#  ('aircraft_registration_B-HLM', 118.68147958344262),
#  ('aircraft_registration_B-16310', 118.59701237881892),
#  ('aircraft_registration_B-LNT', 118.5704456698912),
#  ('aircraft_registration_B-18352', 114.82177800407271),
#  ('airline_EVA Air (Hello Kitty Sanrio Family Livery)', 114.7159372042307),
#  ('aircraft_registration_B-16703', 114.71593720404425),
#  ('aircraft_model_Airbus A330-343', 113.1247382111597),
#  ('flight_callsign_HDA487', 110.72715598528708),
#  ('aircraft_registration_B-LRC', 108.4415586417467),
#  ('aircraft_registration_B-18807', 107.02266325683837),
#  ('aircraft_registration_B-18901', 106.93069699465559),
#  ('aircraft_registration_B-16481', 106.71528942287273),
#  ('aircraft_registration_B-KPS', 105.71700374309472),
#  ('aircraft_model_Boeing 777-367', 104.30536309418483),
#  ('aircraft_registration_B-LRA', 103.66984304910483),
#  ('aircraft_registration_B-HLN', 100.72813362050823),
#  ('flight_callsign_EVA6527', 99.02714308093634),
#  ('aircraft_registration_B-LAN', 97.89079145397874),
#  ('aircraft_registration_B-HTI', 97.8901596450616),
#  ('aircraft_model_Airbus A330-223', 95.27533510318338),
#  ('flight_callsign_FDX169', 94.69110482766934),
#  ('aircraft_model_Boeing 777-FS2', 94.69110482764148),
#  ('aircraft_registration_B-HNE', 94.29706133177686),
#  ('aircraft_model_Boeing 777-267', 92.95621115463246),
#  ('aircraft_registration_B-16220', 92.5002780988158),
#  ('aircraft_registration_B-HNF', 92.3311981889056),
#  ('aircraft_registration_B-16701', 92.03351697285801),
#  ('flight_callsign_EVA857', 91.59916045528536),
#  ('aircraft_registration_B-18903', 91.1770601381842),
#  ('aircraft_model_Airbus A330-243', 90.95272136091029),
#  ('aircraft_model_Boeing 737-8SH', 89.96091825518397),
#  ('aircraft_registration_B-18659', 89.96091825518079),
#  ('airline_Mandarin Airlines (Taichung Livery)', 89.96091825509745),
#  ('aircraft_registration_B-16221', 89.18079401309969),
#  ('aircraft_registration_B-HXH', 89.0270880954566),
#  ('aircraft_registration_B-LNZ', 88.85420616438644),
#  ('aircraft_registration_B-18301', 87.4618043621324),
#  ('aircraft_model_Airbus A340-313', 83.62607054330624),
#  ('aircraft_registration_B-HNB', 82.09943262476195),
#  ('aircraft_registration_B-18360', 76.02147511262096),
#  ('aircraft_registration_B-LNX', 72.20549490384167),
#  ('aircraft_registration_B-18711', 71.36195121637833),
#  ('aircraft_registration_B-LRD', 68.06731487863058),
#  ('aircraft_registration_B-LDH', 66.75014365309153),
#  ('aircraft_model_Airbus A350-941', 66.55100744321601),
#  ('aircraft_registration_B-HSD', 65.47161862664427),
#  ('aircraft_registration_B-LBB', 64.55120836773202),
#  ('aircraft_registration_B-HNQ', 64.277454929557),
#  ('aircraft_registration_B-18665', 62.696587141848006),
#  ('aircraft_registration_B-HNH', 62.13557523673832),
#  ('aircraft_registration_B-HNA', 61.30246823167202),
#  ('aircraft_registration_B-LIF', 58.50701162687049),
#  ('aircraft_registration_B-KPC', 58.189983217966216),
#  ('aircraft_registration_B-LBA', 55.95618887602342),
#  ('flight_callsign_CPA3331', 54.080147535332934),
#  ('aircraft_registration_B-18359', 53.76652038754989),
#  ('aircraft_registration_B-HLV', 53.59590138825979),
#  ('aircraft_model_Boeing 747-4R7(F)', 53.01278308864289),
#  ('airline_UPS', 53.01278308859348),
#  ('flight_callsign_UPS54', 53.012783088582395),
#  ('aircraft_registration_B-LNY', 52.627208696808225),
#  ('aircraft_registration_B-16712', 51.7033067563673),
#  ('aircraft_registration_B-18803', 49.184335801162305),
#  ('aircraft_registration_B-16406', 47.9584890184062),
#  ('aircraft_model_Boeing 747-45E(BDSF)', 47.95848901837688),
#  ('aircraft_registration_B-LAP', 46.5973858931473),
#  ('flight_callsign_EVA1357', 45.42534708769405),
#  ('aircraft_registration_B-18208', 43.07331080541679),
#  ('aircraft_model_Boeing 747-409', 43.07331080536525),
#  ('aircraft_registration_B-HTJ', 42.95110164269762),
#  ('aircraft_registration_B-HSN', 40.56352377980221),
#  ('aircraft_registration_B-LNU', 38.883005386887476),
#  ('aircraft_registration_B-18715', 37.455866570299875),
#  ('aircraft_registration_B-LNM', 36.625947574126336),
#  ('flight_callsign_CPA463', 35.33003587135738),
#  ('aircraft_registration_B-LAB', 34.99883313723359),
#  ('aircraft_registration_B-LIB', 34.64001402927636),
#  ('aircraft_registration_B-LNR', 34.52827800744717),
#  ('aircraft_registration_N612FE', 33.67098250485662),
#  ('aircraft_registration_B-18609', 33.4671104056541),
#  ('aircraft_registration_B-LNN', 33.38987546509996),
#  ('aircraft_registration_B-KPK', 31.88287609702414),
#  ('aircraft_model_Airbus A330-302', 31.837105334967646),
#  ('aircraft_registration_B-18315', 30.373244521554476),
#  ('aircraft_registration_B-HTK', 29.8540617710526),
#  ('aircraft_registration_B-LNW', 28.684068978345408),
#  ('aircraft_registration_B-HST', 27.90886284930083),
#  ('aircraft_registration_B-18316', 27.773099660237445),
#  ('aircraft_registration_B-18353', 26.13492339942367),
#  ('aircraft_registration_B-18706', 26.010624343940037),
#  ('aircraft_registration_B-LNO', 24.0405617987709),
#  ('aircraft_registration_N454PA', 23.569345838266123),
#  ('aircraft_model_Boeing 747-46N(F)', 23.56934583824978),
#  ('flight_callsign_EVA867', 23.4650223256546),
#  ('flight_callsign_EVA6537', 22.86156927526099),
#  ('aircraft_registration_B-18358', 22.356357536015807),
#  ('airline_China Airlines (Masalu! Taiwan Livery)', 22.35635753598786),
#  ('aircraft_registration_B-LNE', 21.47480898381071),
#  ('aircraft_registration_B-HTH', 20.889000086623156),
#  ('aircraft_registration_B-18053', 19.923675946735706),
#  ('airline_China Airlines (Welcome to Taiwan Livery)', 19.26512799946975),
#  ('aircraft_registration_B-18355', 19.265127999424625),
#  ('flight_callsign_BR857', 18.97661035770858),
#  ('aircraft_registration_B-LND', 18.647752182059502),
#  ('aircraft_registration_B-18001', 18.50485570896994),
#  ('flight_callsign_CPA465', 12.28624748695664),
#  ('aircraft_registration_B-LBG', 11.996612839733828),
#  ('aircraft_registration_B-18351', 11.816794783834133),
#  ('aircraft_registration_B-HLD', 10.320178780061724),
#  ('flight_callsign_CAL915', 10.02323551140239),
#  ('aircraft_registration_B-HNP', 9.698830528637501),
#  ('aircraft_registration_B-18905', 9.680746727243076),
#  ('aircraft_registration_B-LNI', 8.974730961745507),
#  ('displacement_to_hkg', 8.847817021713865),
#  ('heading', 8.731624744900092),
#  ('speed', 7.6581589769195295),
#  ('aircraft_registration_B-LDC', 6.667111702499454),
#  ('aircraft_registration_B-16710', 6.0505361117149405),
#  ('aircraft_registration_B-16483', 5.095221445642437),
#  ('aircraft_model_Boeing 777-35E(ER)', 2.0296905009164306),
#  ('altitude', 0.022107002173646608),
#  ('flight_callsign_CPA35', 3.907985046680551e-10),
#  ('flight_callsign_CAL2919', 3.531113179633394e-10),
#  ('aircraft_registration_B-HKX', 9.607958872948075e-11),
#  ('aircraft_registration_B-HLJ', 9.14610609470401e-11),
#  ('aircraft_registration_B-18657', 9.015366231324151e-11),
#  ('aircraft_registration_B-18661', 8.674305718159303e-11),
#  ('aircraft_registration_B-LJI', 8.354561487067258e-11),
#  ('aircraft_registration_B-KPA', 7.771916443743976e-11),
#  ('aircraft_registration_B-18666', 6.789946382923517e-11),
#  ('aircraft_registration_B-HND', 6.081535275370697e-11),
#  ('aircraft_registration_B-16401', 4.956746124662459e-11),
#  ('aircraft_registration_B-18656', 4.934008757118136e-11),
#  ('flight_callsign_HX285', 4.427391786521184e-11),
#  ('aircraft_registration_B-LAI', 4.234834705130197e-11),
#  ('aircraft_registration_B-18651', 4.001776687800884e-11),
#  ('aircraft_registration_B-LAG', 2.0122570276726037e-11),
#  ('aircraft_registration_B-LIA', 1.531930138298776e-11),
#  ('flight_callsign_NCA699', 1.3713474800169934e-11),
#  ('aircraft_registration_B-HLR', 1.2107648217352107e-11),
#  ('aircraft_registration_B-HSJ', 6.423306331271306e-12),
#  ('aircraft_registration_B-KQK', 1.1226575225009583e-12),
#  ('aircraft_registration_JA04KZ', 0.0),
#  ('aircraft_registration_N450PA', 0.0),
#  ('aircraft_model_Boeing 737-8FH', 0.0),
#  ('aircraft_model_Boeing 747-412(BCF)', 0.0),
#  ('aircraft_model_Boeing 747-481(F)', 0.0),
#  ('airline_Nippon Cargo Airlines (Green freighter Livery)', 0.0)]

# %%
df_test_true_pred.shape
# Out:
# (158, 3)

# %%
df_test_true_pred[df_test_true_pred['diff'] < 0].shape # if true < pred => late
# Out:
# (78, 3)

# %%
df_test_true_pred[df_test_true_pred.pred < 0].shape
# Out:
# (0, 3)

# %%
df_test_true_pred.true.hist()

# %%
def regression_diagnostic_plots(df_true_pred):
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
    axes = axes.ravel()
    
    
    # Residual Plot: Validating the assumption of linearity
    sns.residplot('pred', 'true', data=df_true_pred,lowess=True,
                  line_kws={'color': 'red', 'lw': 1, 'alpha': 1}, 
                  ax=axes[0])
    axes[0].set_title('Residual Plot')
    axes[0].set_ylabel('Residuals')
    axes[0].set_xlabel('Fitted Values')
    
    residuals = df_true_pred['true'] - df_true_pred['pred']
    
    # Normal Q-Q Plot: Validating the assumption of normally distributed residuals (errors)
    stats.probplot(residuals, dist='norm', plot=axes[1])
    axes[1].set_title('Normal Q-Q Plot')
    
    
    # Scale-Location plot: Validating the assumption of homoscedasticity of residuals
    model_norm_residuals_abs_sqrt=np.sqrt(np.abs(residuals))

    sns.regplot(df_true_pred['pred'], model_norm_residuals_abs_sqrt,
                scatter=True,
                lowess=True,
                line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8}, 
                ax=axes[2])
    axes[2].set_title("Scale-Location Plot")
    axes[2].set_ylabel("Standarized Residuals")
    axes[2].set_xlabel("Fitted Values")
    
    axes[3].axis('off')
    
    fig.tight_layout()

# %%
regression_diagnostic_plots(df_test_true_pred)

# %% [markdown]
# **Standardization of features**

# %%
ss = StandardScaler()
ss.fit(X_train)
X_train_sc = ss.transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
r_alphas = np.logspace(0, 5, 200)
ridge_model = RidgeCV(alphas=r_alphas, store_cv_values=True)
ridge_model = ridge_model.fit(X_train_sc, y_train)

y_test_pred = ridge_model.predict(X_test_sc)

test_regression_metrics = get_regression_metrics(y_test, y_test_pred, X_test.shape[1])
df_test_true_pred = pd.DataFrame(columns=['true', 'pred'])
df_test_true_pred = df_test_true_pred.assign(true=y_test)
df_test_true_pred = df_test_true_pred.assign(pred=y_test_pred)
df_test_true_pred['diff'] = df_test_true_pred['true'] - df_test_true_pred['pred']

# %%
df_test_regression_metrics = pd.DataFrame()
df_test_true_pred = pd.DataFrame(columns=['model_name', 'true', 'pred'])

# %%
def gridsearch_model_evaluation(model_name, model, hyper_param):
    clf_pipe = Pipeline([
        ('clf', model)
    ])
#   
    print(clf_pipe.get_params().keys())
    gs = GridSearchCV(clf_pipe, 
                      param_grid=hyper_param, 
#                       cv=cv, 
                      verbose=10, n_jobs=-1)
    gs.fit(X_train_sc, y_train)
    
    print(model_name)
    print('Best Score: {}'.format(gs.best_score_))
    print('Best Params: {}'.format(gs.best_params_))
    
    # Best Model
    grid_model = gs.best_estimator_
    
    print('Model Score on X_train: {}'.format(grid_model.score(X_train_sc, y_train)))
    
    # Prediction and score
    y_test_pred = grid_model.predict(X_test_sc)

    test_regression_metrics = get_regression_metrics(y_test, y_test_pred, X_test.shape[1])
    test_regression_metrics['model_name'] = model_name
    
    return test_regression_metrics, y_test_pred

# %% [markdown]
# ## Ridge Regression

# %%
test_regression_metrics, y_test_pred = gridsearch_model_evaluation('Ridge Regression',
                                                                    Ridge(),
                                                                    {'clf__alpha': np.logspace(0, 5, 200)})

df_test_regression_metrics = df_test_regression_metrics.append(test_regression_metrics, ignore_index=True)

# %% [markdown]
# ## Lasso Regression

# %%
test_regression_metrics, y_test_pred = gridsearch_model_evaluation('Lasso Regression',
                                                                    Lasso(),
                                                                    {'clf__alpha': np.arange(0.001, 0.15, 0.0025)}
                                                                   )

df_test_regression_metrics = df_test_regression_metrics.append(test_regression_metrics, ignore_index=True)

# %% [markdown]
# ## ElasticNet Regression

# %%
test_regression_metrics, y_test_pred = gridsearch_model_evaluation('ElasticNet Regression',
                                                                    ElasticNet(),
                                                                    {'clf__alpha': np.arange(0.5, 1.0, 0.005),
                                                                     'clf__l1_ratio': [0.5]}
                                                                   )

df_test_regression_metrics = df_test_regression_metrics.append(test_regression_metrics, ignore_index=True)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'clf', 'clf__alpha', 'clf__copy_X', 'clf__fit_intercept', 'clf__l1_ratio', 'clf__max_iter', 'clf__normalize', 'clf__positive', 'clf__precompute', 'clf__random_state', 'clf__selection', 'clf__tol', 'clf__warm_start'])
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed:   16.2s
# ElasticNet Regression
# Best Score: 0.748698211349665
# Best Params: {'clf__alpha': 0.5, 'clf__l1_ratio': 0.5}
# Model Score on X_train: 0.7491252783369184
# Mean squared error      =  191366.78083000434
# Root mean squared error =  437.4548900515393
# Median absolute error   =  306.0676032373449
# R^2                     =  0.7495389548636724
# Adjusted R^2            =  0.7479897112855096
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   17.5s finished

# %% [markdown]
# ## Random Forest Regression

# %%
# https://gdcoder.com/decision-tree-regressor-explained-in-depth/
# https://medium.com/datadriveninvestor/random-forest-regression-9871bc9a25eb
test_regression_metrics, y_test_pred = gridsearch_model_evaluation('Random Forest Regression',
                                                                    RandomForestRegressor(),
                                                                    {'clf__max_depth': range(3,7),
                                                                     'clf__n_estimators': np.arange(10, 70, 10)}
                                                                   )

df_test_regression_metrics = df_test_regression_metrics.append(test_regression_metrics, ignore_index=True)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'clf', 'clf__bootstrap', 'clf__ccp_alpha', 'clf__criterion', 'clf__max_depth', 'clf__max_features', 'clf__max_leaf_nodes', 'clf__max_samples', 'clf__min_impurity_decrease', 'clf__min_impurity_split', 'clf__min_samples_leaf', 'clf__min_samples_split', 'clf__min_weight_fraction_leaf', 'clf__n_estimators', 'clf__n_jobs', 'clf__oob_score', 'clf__random_state', 'clf__verbose', 'clf__warm_start'])
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   44.6s
# [Parallel(n_jobs=-1)]: Done 110 out of 120 | elapsed:   57.6s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:  1.1min finished
# Random Forest Regression
# Best Score: 0.7463381276272063
# Best Params: {'clf__max_depth': 6, 'clf__n_estimators': 60}
# Model Score on X_train: 0.7519384257143227
# Mean squared error      =  192476.0774742128
# Root mean squared error =  438.72095627427325
# Median absolute error   =  321.82503862933936
# R^2                     =  0.7480871062425605
# Adjusted R^2            =  0.7465288821574629

# %% [markdown]
# ## Support Vector Regression

# %%
# https://medium.com/pursuitnotes/support-vector-regression-in-6-steps-with-python-c4569acd062d
# https://stackoverflow.com/questions/40568808/coefficient-in-support-vector-regression-svr-using-grid-search-gridsearchcv

test_regression_metrics, y_test_pred = gridsearch_model_evaluation('Support Vector Regression',
                                                                    SVR(),
                                                                    {'clf__kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
                                                                     'clf__C': np.logspace(-3, 2, 2),
                                                                     'clf__gamma': np.logspace(-5, 2, 2)}
                                                                   )

df_test_regression_metrics = df_test_regression_metrics.append(test_regression_metrics, ignore_index=True)

# %% [markdown]
# ## AdaBoost Regression

# %%
# https://www.programcreek.com/python/example/86712/sklearn.ensemble.AdaBoostRegressor
ada = AdaBoostRegressor(base_estimator=DecisionTreeRegressor()) 
test_regression_metrics, y_test_pred = gridsearch_model_evaluation('AdaBoost Regression',
                                                                    ada,
                                                                    {'clf__n_estimators': [25, 50],
                                                                     'clf__base_estimator__max_depth': [1,2],
                                                                     'clf__learning_rate': np.arange(0.4, 1.1, 0.1)
                                                                    }
                                                                   )

df_test_regression_metrics = df_test_regression_metrics.append(test_regression_metrics, ignore_index=True)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'clf', 'clf__base_estimator__ccp_alpha', 'clf__base_estimator__criterion', 'clf__base_estimator__max_depth', 'clf__base_estimator__max_features', 'clf__base_estimator__max_leaf_nodes', 'clf__base_estimator__min_impurity_decrease', 'clf__base_estimator__min_impurity_split', 'clf__base_estimator__min_samples_leaf', 'clf__base_estimator__min_samples_split', 'clf__base_estimator__min_weight_fraction_leaf', 'clf__base_estimator__presort', 'clf__base_estimator__random_state', 'clf__base_estimator__splitter', 'clf__base_estimator', 'clf__learning_rate', 'clf__loss', 'clf__n_estimators', 'clf__random_state'])
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 132 out of 140 | elapsed:  1.4min remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done 140 out of 140 | elapsed:  1.5min finished
# AdaBoost Regression
# Best Score: 0.6911303008061205
# Best Params: {'clf__base_estimator__max_depth': 2, 'clf__learning_rate': 0.4, 'clf__n_estimators': 25}
# Model Score on X_train: 0.694464151204999
# Mean squared error      =  233358.35144418868
# Root mean squared error =  483.0717870505259
# Median absolute error   =  387.2135305452839
# R^2                     =  0.6945803428343085
# Adjusted R^2            =  0.6926911490786445

# %% [markdown]
# ## XGBoost

# %%
# https://www.datacamp.com/community/tutorials/xgboost-in-python
# https://www.kaggle.com/phunter/xgboost-with-gridsearchcv
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/

# %%
model_names = [
#                'Linear Regression',
               'Ridge Regression',
               'Lasso Regression'
]

models = [
#          LinearRegression(),
         Ridge(),
         Lasso()
         
        ]

hyper_params = [
#                 {},
                {
                    'clf__alpha': np.logspace(0, 5, 10)
                },
                {
#                     'clf__alpha': np.arange(0.001, 0.15, 0.0025)
                    'clf__alpha': np.arange(0.001, 0.005, 0.0025)
                }
]

# %%
# df_test_regression_metrics = pd.DataFrame()

for model_name, model, hyper_param in zip(model_names, models, hyper_params):
